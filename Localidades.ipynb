# %%
import numpy as np
import pandas as pd

# %%
#Se define la ruta de la información.
data_localidades = "../Data/localidades.csv"

# %%
#Leemos los datos del archivo
data = pd.read_csv(data_localidades, sep=",", encoding="UTF-8")

# %%
data.sample(10)
# Out:
#       localidad_id    localidad_nombre  localidad_centroide_lat  \
# 749     6721020000          SALLIQUELO               -36.751165
# 1603   14168110000           SINSACATE               -30.942857
# 966    10056060000            VILISMAN               -28.502113
# 3807   82133150000            TARTAGAL               -28.672210
# 2093   34014070000    VILLA DEL CARMEN               -26.252259
# 3881   86070050000        KILOMETRO 30               -27.384504
# 249     6266020000   CAPILLA DEL SE¥OR               -34.291211
# 98      6098010010       VILLA PORTEÑA               -34.891043
# 2635   50098045000  BARRIO LA ESTACION               -33.155290
# 3398   78007020000   PUERTO SANTA CRUZ               -50.017189
#
#       localidad_centroide_lon  provincia_id     provincia_nombre  \
# 749                -62.959957             6         Buenos Aires
# 1603               -64.088497            14              Córdoba
# 966                -65.438549            10            Catamarca
# 3807               -59.846820            82             Santa Fe
# 2093               -58.252553            34              Formosa
# 3881               -63.529677            86  Santiago del Estero
# 249                -59.101523             6         Buenos Aires
# 98                 -57.896377             6         Buenos Aires
# 2635               -68.354362            50              Mendoza
# 3398               -68.524825            78           Santa Cruz
#
#       departamento_id    departamento_nombre  municipio_id  \
# 749            6721.0             Salliqueló       60721.0
# 1603          14168.0                Totoral      141533.0
# 966           10056.0                El Alto      100147.0
# 3807          82133.0                   Vera      824198.0
# 2093          34014.0                Formosa      340028.0
# 3881          86070.0               Figueroa           NaN
# 249            6266.0  Exaltación de la Cruz       60266.0
# 98             6098.0                Berisso       60098.0
# 2635          50098.0             San Martín      500035.0
# 3398          78007.0            Corpen Aike           NaN
#
#            municipio_nombre  localidad_censal_id localidad_censal_nombre  \
# 749              Salliqueló              6721020              Salliqueló
# 1603              Sinsacate             14168110               Sinsacate
# 966                 El Alto             10056060                Vilismán
# 3807               Tartagal             82133150                Tartagal
# 2093                Formosa             34014070        Villa del Carmen
# 3881                    NaN             86070050            Kilómetro 30
# 249   Exaltación de la Cruz              6266020       Capilla del Señor
# 98                  Berisso              6098010                 Berisso
# 2635                  Junín             50098045      Barrio La Estación
# 3398                    NaN             78007020       Puerto Santa Cruz
#
#      localidad_categoria
# 749     Localidad simple
# 1603    Localidad simple
# 966     Localidad simple
# 3807    Localidad simple
# 2093    Localidad simple
# 3881    Localidad simple
# 249     Localidad simple
# 98               Entidad
# 2635    Localidad simple
# 3398    Localidad simple

# %%
data_provincia = data.groupby('provincia_nombre')

# %%
data_provincia.localidad_id.count()
# Out:
# provincia_nombre
# Buenos Aires                                             893
# Catamarca                                                182
# Chaco                                                     91
# Chubut                                                    90
# Ciudad Autónoma de Buenos Aires                           49
# Corrientes                                                77
# Córdoba                                                  568
# Entre Ríos                                               176
# Formosa                                                   64
# Jujuy                                                    161
# La Pampa                                                  89
# La Rioja                                                  92
# Mendoza                                                  213
# Misiones                                                 140
# Neuquén                                                   61
# Río Negro                                                162
# Salta                                                    147
# San Juan                                                  99
# San Luis                                                  93
# Santa Cruz                                                27
# Santa Fe                                                 386
# Santiago del Estero                                      165
# Tierra del Fuego, Antártida e Islas del Atlántico Sur      4
# Tucumán                                                  113
# Name: localidad_id, dtype: int64

# %%
# Quiero ver si existe Palermo Chico

print(any(data.localidad_nombre == "PALERMO CHICO"))
print(any(data.localidad_censal_nombre == "Palermo Chico"))
print(any(data.localidad_nombre == "PARQUE CENTENARIO"))
# Out:
# False
# False
# False
