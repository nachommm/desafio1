# %%
import numpy as np
import pandas as pd

# %%
#Se define la ruta de la información.
data_localidades = "../Data/localidades.csv"

# %%
#Leemos los datos del archivo
data = pd.read_csv(data_localidades, sep=",", encoding="UTF-8")

# %%
data.sample(10)
# Out:
#       localidad_id     localidad_nombre  localidad_centroide_lat  \
# 2545   50049050012  SIERRAS DE ENCALADA               -32.986946
# 2269   38084055000            OLACAPATO               -24.115281
# 1956   30028080000   LOS CONQUISTADORES               -30.594407
# 2750   54049050000          SAN ANTONIO               -26.055784
# 3617   82070090000              HIPATIA               -31.128252
# 202     6203080000          SANTA MARIA               -37.556586
# 1340   14098050000           BERROTARAN               -32.452867
# 462     6441030024         VILLA ELVIRA               -34.940644
# 2941   62042030000      BARDA DEL MEDIO               -38.724663
# 2429   46042090000            NONOGASTA               -29.304096
#
#       localidad_centroide_lon  provincia_id provincia_nombre  departamento_id  \
# 2545               -68.948509            50          Mendoza          50049.0
# 2269               -66.718651            38            Jujuy          38084.0
# ...

# %%
data_provincia = data.groupby('provincia_nombre')

# %%
data_provincia.localidad_id.count()
# Out:
# provincia_nombre
# Buenos Aires                                             893
# Catamarca                                                182
# Chaco                                                     91
# Chubut                                                    90
# Ciudad Autónoma de Buenos Aires                           49
# Corrientes                                                77
# Córdoba                                                  568
# Entre Ríos                                               176
# Formosa                                                   64
# Jujuy                                                    161
# La Pampa                                                  89
# La Rioja                                                  92
# Mendoza                                                  213
# Misiones                                                 140
# Neuquén                                                   61
# ...

# %%
# Quiero ver si existe Palermo Chico

print(any(data.localidad_nombre == "PALERMO CHICO"))
print(any(data.localidad_censal_nombre == "Palermo Chico"))
print(any(data.localidad_nombre == "PARQUE CENTENARIO"))
# Out:
# False
# False
# False
