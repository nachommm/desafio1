# %%
import numpy as np
import pandas as pd

# %%
#Se define la ruta de la información.
data_localidades = "../Data/localidades.csv"

# %%
#Leemos los datos del archivo
data = pd.read_csv(data_localidades, sep=",", encoding="UTF-8")

# %%
data.sample(10)
# Out:
#       localidad_id         localidad_nombre  localidad_centroide_lat  \
# 3115   66056090002  MISION TIERRAS FISCALES               -23.264456
# 2345   42098010000            CARRO QUEMADO               -36.475565
# 2729   54035040000              SANTA MARIA               -27.929285
# 3767   82119090000                   PUJATO               -33.019573
# 1596   14168030000         CAPILLA DE SITON               -30.572964
# 2135   34056020000              EL COLORADO               -26.311735
# 2087   34014010000         COLONIA PASTORIL               -25.670140
# 1419   14119130000                 MANFREDI               -31.844059
# 3613   82070050000                ESPERANZA               -31.450597
# 3601   82063140000                   RECREO               -31.493581
#
#       localidad_centroide_lon  provincia_id provincia_nombre  departamento_id  \
# 3115               -64.005265            66            Salta          66056.0
# 2345               -65.342916            42         La Pampa          42098.0
# 2729               -55.412057            54         Misiones          54035.0
# 3767               -61.043832            82         Santa Fe          82119.0
# 1596               -63.651742            14          Córdoba          14168.0
# 2135               -59.368443            34          Formosa          34056.0
# 2087               -58.262630            34          Formosa          34014.0
# 1419               -63.746075            14          Córdoba          14119.0
# 3613               -60.931007            82         Santa Fe          82070.0
# 3601               -60.735411            82         Santa Fe          82063.0
#
#              departamento_nombre  municipio_id   municipio_nombre  \
# 3115  General José de San Martín      660133.0        Embarcación
# 2345                    Loventué      420070.0      Carro Quemado
# 2729                  Concepción      540133.0        Santa María
# 3767                 San Lorenzo      824009.0             Pujato
# 1596                     Totoral      143176.0  Capilla del Sitón
# 2135                      Pirané      340224.0        El Colorado
# 2087                     Formosa      345014.0   Colonia Pastoril
# 1419                 Río Segundo      141036.0           Manfredi
# 3613                Las Colonias      820161.0          Esperanza
# 3601                  La Capital      820144.0             Recreo
#
#       localidad_censal_id localidad_censal_nombre  \
# 3115             66056090             Embarcación
# 2345             42098010           Carro Quemado
# 2729             54035040             Santa María
# 3767             82119090                  Pujato
# 1596             14168030        Capilla de Sitón
# 2135             34056020             El Colorado
# 2087             34014010        Colonia Pastoril
# 1419             14119130                Manfredi
# 3613             82070050               Esperanza
# 3601             82063140                  Recreo
#
#                     localidad_categoria
# 3115                            Entidad
# 2345                   Localidad simple
# 2729                   Localidad simple
# 3767                   Localidad simple
# 1596                   Localidad simple
# 2135                   Localidad simple
# 2087                   Localidad simple
# 1419                   Localidad simple
# 3613                   Localidad simple
# 3601  Componente de localidad compuesta

# %%
data_provincia = data.groupby('provincia_nombre')

# %%
data_provincia.localidad_id.count()
# Out:
# provincia_nombre
# Buenos Aires                                             893
# Catamarca                                                182
# Chaco                                                     91
# Chubut                                                    90
# Ciudad Autónoma de Buenos Aires                           49
# Corrientes                                                77
# Córdoba                                                  568
# Entre Ríos                                               176
# Formosa                                                   64
# Jujuy                                                    161
# La Pampa                                                  89
# La Rioja                                                  92
# Mendoza                                                  213
# Misiones                                                 140
# Neuquén                                                   61
# Río Negro                                                162
# Salta                                                    147
# San Juan                                                  99
# San Luis                                                  93
# Santa Cruz                                                27
# Santa Fe                                                 386
# Santiago del Estero                                      165
# Tierra del Fuego, Antártida e Islas del Atlántico Sur      4
# Tucumán                                                  113
# Name: localidad_id, dtype: int64
